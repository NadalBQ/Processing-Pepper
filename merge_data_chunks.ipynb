# %% [markdown]
# Here we will merge all runs into a single list to simulate how we could store them in a DDBB

# %%
from glob import glob
import json

# %%
import logging
from bisect import bisect
from logging import getLogger, Formatter, LogRecord, StreamHandler
from typing import Dict


class LevelFormatter(Formatter):
    def __init__(self, formats: Dict[int, str], **kwargs):
        super().__init__()

        if 'fmt' in kwargs:
            raise ValueError(
                'Format string must be passed to level-surrogate formatters, '
                'not this one'
            )

        self.formats = sorted(
            (level, Formatter(fmt, **kwargs)) for level, fmt in formats.items()
        )

    def format(self, record: LogRecord) -> str:
        idx = bisect(self.formats, (record.levelno,), hi=len(self.formats)-1)
        level, formatter = self.formats[idx]
        return formatter.format(record)
    

logger = logging.getLogger()
logger.setLevel(logging.DEBUG)

if not logger.hasHandlers():
    handler = StreamHandler()
    formatter = LevelFormatter(
        {
            logging.DEBUG: '\033[94m[%(asctime)s - %(lineno)d] DEBUG\033[0m: %(message)s',
            logging.INFO: '\033[94mINFO\033[0m: %(message)s',
            logging.WARNING: '\033[93mWARNING\033[0m: %(message)s',
            logging.ERROR: '\033[91mERROR\033[0m: %(message)s',
            logging.CRITICAL: '\033[91mCRITICAL\033[0m: %(message)s'
        }
    )
    handler.setFormatter(formatter)
    logger.addHandler(handler)

logger.info("Logger set up successfully")
# Out:
# INFO: Logger set up successfully

# %%
file_names = glob("./prototype data/*")
logger.debug(file_names)
# Out:
# [2024-09-29 17:52:18,861 - 2] DEBUG: ['./prototype data/celeste_asc_4400.json', './prototype data/celeste_asc_4800.json', './prototype data/celeste_asc_5600.json', './prototype data/celeste_asc_6000.json', './prototype data/celeste_asc_7200.json', './prototype data/celeste_desc_4200.json', './prototype data/celeste_desc_5000.json', './prototype data/celeste_desc_200.json', './prototype data/celeste_desc_6600.json', './prototype data/celeste_asc_0.json', './prototype data/celeste_desc_7800.json', './prototype data/celeste_desc_7400.json', './prototype data/celeste_desc_5200.json', './prototype data/celeste_desc_4000.json', './prototype data/celeste_desc_6800.json', './prototype data/celeste_desc_7600.json', './prototype data/celeste_desc_6400.json', './prototype data/celeste_asc_5400.json', './prototype data/celeste_asc_4600.json', './prototype data/celeste_asc_5800.json', './prototype data/celeste_asc_7000.json', './prototype data/celeste_asc_6200.json', './prototype data/celeste_desc_6000.json', './prototype data/celeste_desc_7200.json', './prototype data/celeste_desc_800.json', './prototype data/celeste_desc_4400.json', './prototype data/celeste_desc_4800.json', './prototype data/celeste_desc_400.json', './prototype data/celeste_desc_5600.json', './prototype data/celeste_asc_6600.json', './prototype data/celeste_asc_7800.json', './prototype data/celeste_asc_7400.json', './prototype data/celeste_asc_4200.json', './prototype data/celeste_asc_5000.json', './prototype data/celeste_asc_6800.json', './prototype data/celeste_asc_7600.json', './prototype data/celeste_asc_6400.json', './prototype data/celeste_asc_5200.json', './prototype data/celeste_asc_4000.json', './prototype data/celeste_desc_7000.json', './prototype data/celeste_desc_6200.json', './prototype data/celeste_desc_600.json', './prototype data/celeste_desc_5400.json', './prototype data/celeste_desc_4600.json', './prototype data/celeste_desc_5800.json', './prototype data/celeste_asc_8000.json', './prototype data/celeste_desc_1600.json', './prototype data/celeste_asc_9200.json', './prototype data/celeste_desc_2000.json', './prototype data/celeste_desc_3200.json', './prototype data/celeste_desc_8600.json', './prototype data/celeste_desc_9800.json', './prototype data/celeste_desc_9400.json', './prototype data/celeste_asc_1000.json', './prototype data/celeste_asc_3800.json', './prototype data/celeste_asc_2600.json', './prototype data/celeste_asc_3400.json', './prototype data/celeste_asc_1200.json', './prototype data/celeste_desc_8800.json', './prototype data/celeste_desc_9600.json', './prototype data/celeste_desc_8400.json', './prototype data/celeste_asc_3600.json', './prototype data/celeste_asc_2800.json', './prototype data/celeste_asc_2400.json', './prototype data/celeste_asc_9000.json', './prototype data/celeste_desc_1400.json', './prototype data/celeste_desc_1800.json', './prototype data/celeste_asc_8200.json', './prototype data/celeste_desc_3000.json', './prototype data/celeste_desc_0.json', './prototype data/celeste_asc_200.json', './prototype data/celeste_desc_2200.json', './prototype data/celeste_asc_2000.json', './prototype data/celeste_asc_3200.json', './prototype data/celeste_desc_8000.json', './prototype data/celeste_asc_1600.json', './prototype data/celeste_desc_9200.json', './prototype data/celeste_desc_3800.json', './prototype data/celeste_asc_600.json', './prototype data/celeste_desc_2600.json', './prototype data/celeste_desc_3400.json', './prototype data/celeste_asc_8600.json', './prototype data/celeste_asc_9800.json', './prototype data/celeste_asc_9400.json', './prototype data/celeste_desc_1000.json', './prototype data/celeste_desc_3600.json', './prototype data/celeste_asc_800.json', './prototype data/celeste_desc_2800.json', './prototype data/celeste_desc_2400.json', './prototype data/celeste_asc_400.json', './prototype data/celeste_asc_8800.json', './prototype data/celeste_desc_1200.json', './prototype data/celeste_asc_9600.json', './prototype data/cele ...

# %%
from typing import List


file_data: List = []


for file_name in file_names:
    logger.debug(file_name)

    with open(file_name, "r") as fp:
        data_chunk: List = json.load(fp)["data"]

        logger.debug(f"chunk length: {len(data_chunk)}")
        file_data.extend(data_chunk)


logger.info(len(file_data))
logger.debug(file_data[0])
# Out:
# [2024-09-29 18:05:18,795 - 8] DEBUG: ./prototype data/celeste_asc_4400.json
# [2024-09-29 18:05:18,827 - 13] DEBUG: chunk length: 200
# [2024-09-29 18:05:18,828 - 8] DEBUG: ./prototype data/celeste_asc_4800.json
# [2024-09-29 18:05:19,081 - 13] DEBUG: chunk length: 200
# [2024-09-29 18:05:19,082 - 8] DEBUG: ./prototype data/celeste_asc_5600.json
# [2024-09-29 18:05:19,119 - 13] DEBUG: chunk length: 200
# [2024-09-29 18:05:19,122 - 8] DEBUG: ./prototype data/celeste_asc_6000.json
# [2024-09-29 18:05:19,150 - 13] DEBUG: chunk length: 200
# [2024-09-29 18:05:19,153 - 8] DEBUG: ./prototype data/celeste_asc_7200.json
# [2024-09-29 18:05:19,184 - 13] DEBUG: chunk length: 200
# [2024-09-29 18:05:19,189 - 8] DEBUG: ./prototype data/celeste_desc_4200.json
# [2024-09-29 18:05:19,268 - 13] DEBUG: chunk length: 200
# [2024-09-29 18:05:19,270 - 8] DEBUG: ./prototype data/celeste_desc_5000.json
# [2024-09-29 18:05:19,290 - 13] DEBUG: chunk length: 200
# [2024-09-29 18:05:19,293 - 8] DEBUG: ./prototype data/celeste_desc_200.json
# [2024-09-29 18:05:19,315 - 13] DEBUG: chunk length: 200
# [2024-09-29 18:05:19,317 - 8] DEBUG: ./prototype data/celeste_desc_6600.json
# [2024-09-29 18:05:19,354 - 13] DEBUG: chunk length: 200
# [2024-09-29 18:05:19,355 - 8] DEBUG: ./prototype data/celeste_asc_0.json
# [2024-09-29 18:05:19,465 - 13] DEBUG: chunk length: 200
# [2024-09-29 18:05:19,467 - 8] DEBUG: ./prototype data/celeste_desc_7800.json
# [2024-09-29 18:05:19,502 - 13] DEBUG: chunk length: 200
# [2024-09-29 18:05:19,503 - 8] DEBUG: ./prototype data/celeste_desc_7400.json
# [2024-09-29 18:05:19,523 - 13] DEBUG: chunk length: 200
# [2024-09-29 18:05:19,524 - 8] DEBUG: ./prototype data/celeste_desc_5200.json
# [2024-09-29 18:05:19,553 - 13] DEBUG: chunk length: 200
# [2024-09-29 18:05:19,554 - 8] DEBUG: ./prototype data/celeste_desc_4000.json
# [2024-09-29 18:05:19,571 - 13] DEBUG: chunk length: 200
# [2024-09-29 18:05:19,572 - 8] DEBUG: ./prototype data/celeste_desc_6800.json
# [2024-09-29 18:05:19,590 - 13] DEBUG: chunk length: 200
# [2024-09-29 18:05:19,594 - 8] DEBUG: ./prototype data/celeste_desc_7600.json
# [2024-09-29 18:05:19,778 - 13] DEBUG: chunk length: 200
# [2024-09-29 18:05:19,783 - 8] DEBUG: ./prototype data/celeste_desc_6400.json
# [2024-09-29 18:05:19,816 - 13] DEBUG: chunk length: 200
# [2024-09-29 18:05:19,847 - 8] DEBUG: ./prototype data/celeste_asc_5400.json
# [2024-09-29 18:05:19,870 - 13] DEBUG: chunk length: 200
# [2024-09-29 18:05:19,873 - 8] DEBUG: ./prototype data/celeste_asc_4600.json
# [2024-09-29 18:05:19,924 - 13] DEBUG: chunk length: 200
# [2024-09-29 18:05:19,925 - 8] DEBUG: ./prototype data/celeste_asc_5800.json
# [2024-09-29 18:05:19,950 - 13] DEBUG: chunk length: 200
# [2024-09-29 18:05:19,952 - 8] DEBUG: ./prototype data/celeste_asc_7000.json
# [2024-09-29 18:05:19,982 - 13] DEBUG: chunk length: 200
# [2024-09-29 18:05:19,985 - 8] DEBUG: ./prototype data/celeste_asc_6200.json
# [2024-09-29 18:05:20,018 - 13] DEBUG: chunk length: 200
# [2024-09-29 18:05:20,021 - 8] DEBUG: ./prototype data/celeste_desc_6000.json
# [2024-09-29 18:05:20,080 - 13] DEBUG: chunk length: 200
# [2024-09-29 18:05:20,082 - 8] DEBUG: ./prototype data/celeste_desc_7200.json
# [2024-09-29 18:05:20,120 - 13] DEBUG: chunk length: 200
# [2024-09-29 18:05:20,125 - 8] DEBUG: ./prototype data/celeste_desc_800.json
# [2024-09-29 18:05:20,168 - 13] DEBUG: chunk length: 200
# [2024-09-29 18:05:20,169 - 8] DEBUG: ./prototype data/celeste_desc_4400.json
# [2024-09-29 18:05:20,203 - 13] DEBUG: chunk length: 200
# [2024-09-29 18:05:20,206 - 8] DEBUG: ./prototype data/celeste_desc_4800.json
# [2024-09-29 18:05:20,226 - 13] DEBUG: chunk length: 200
# [2024-09-29 18:05:20,229 - 8] DEBUG: ./prototype data/celeste_desc_400.json
# [2024-09-29 18:05:20,244 - 13] DEBUG: chunk length: 200
# [2024-09-29 18:05:20,248 - 8] DEBUG: ./prototype data/celeste_desc_5600.json
# [2024-09-29 18:05:20,281 - 13] DEBUG: chunk length: 200
# [2024-09-29 18:05:20,355 - 8] DEBUG: ./prototype data/celeste_asc_6600.json
# [2024-09-29 18:05:20,366 - 13] DEBUG: chunk length: 200
# [2024-09-29 18:05:20,370 - 8] DEBUG: ./prototype data/celeste_asc_7800.json
# [2024-09-29 18:05:20,394 - 13] DEBUG: chunk length: 200
# [2024-09-29 18:05:20,398 - 8] DEBUG: ./prototype data/celeste_asc_7400.json
# [2024-09-29 18:05:20,416 - 13] DEBUG: chunk length: 200
# [2024-09-29 18:05:20,418 - 8] DEBUG: ./prototype data/celeste_asc_4200.json
# [2024-09-29 18:05:20,444 - 13] DEBUG: chunk length: 200
# [2024-09-29 18:05:20,445 - 8] DEBUG: ./prototype data/celeste_asc_5000.json
# [2024-09-29 18:05:20,466 - 13] DEBUG: chunk length: 200
# [2024-09-29 18:05:20,468 - 8] DEBUG: ./prototype data/celeste_asc_6800.json
# [2024-09-29 18:05:20,485 - 13] DEBUG: chunk length: 200
# [2024-09-29 18:05:20,486 - 8] DEBUG: ./prototype data/celeste_asc_7600.json
# [2024-09-29 18:05:20,508 - 13] DEBUG: chunk length: 200
# [2024-09-29 18:05:20,510 - 8] DEBUG: ./prototype data/celeste_asc_6400.json
# [2024-09-29 18:05:20,529 - 13] DEBUG: chunk length: 200
# [2024-09-29 18:05:20,531 - 8] DEBUG: ./prototype data/celeste_asc_5200.json
# [2024-09-29 18:05:20,547 - 13] DEBUG: chunk length: 200
# [2024-09-29 18:05:20,549 - 8] DEBUG: ./prototype data/celeste_asc_4000.json
# [2024-09-29 18:05:20,577 - 13] DEBUG: chunk length: 200
# [2024-09-29 18:05:20,581 - 8] DEBUG: ./prototype data/celeste_desc_7000.json
# [2024-09-29 18:05:20,592 - 13] DEBUG: chunk length: 200
# [2024-09-29 18:05:20,678 - 8] DEBUG: ./prototype data/celeste_desc_6200.json
# [2024-09-29 18:05:20,702 - 13] DEBUG: chunk length: 200
# [2024-09-29 18:05:20,714 - 8] DEBUG: ./prototype data/celeste_desc_600.json
# [2024-09-29 18:05:20,750 - 13] DEBUG: chunk length: 200
# [2024-09-29 18:05:20,752 - 8] DEBUG: ./prototype data/celeste_desc_5400.json
# [2024-09-29 18:05:20,769 - 13] DEBUG: chunk length: 200
# [2024-09-29 18:05:20,776 - 8] DEBUG: ./prototype data/celeste_desc_4600.json
# [2024-09-29 18:05:20,794 - 13] DEBUG: chunk length: 200
# [2024-09-29 18:05:20,798 - 8] DEBUG: ./prototype data/celeste_desc_5800.json
# [2024-09-29 18:05:20,855 - 13] DEBUG: chunk length: 200
# [2024-09-29 18:05:20,862 - 8] DEBUG: ./prototype data/celeste_asc_8000.json
# [2024-09-29 18:05:20,876 - 13] DEBUG: chunk length: 200
# [2024-09-29 18:05:20,877 - 8] DEBUG: ./prototype data/celeste_desc_1600.json
# [2024-09-29 18:05:21,008 - 13] DEBUG: chunk length: 200
# [2024-09-29 18:05:21,022 - 8] DEBUG: ./prototype data/celeste_asc_9200.json
# [2024-09-29 18:05:21,045 - 13] DEBUG: chunk length: 200
# [2024-09-29 18:05:21,047 - 8] DEBUG: ./prototype data/celeste_desc_2000.json
# [2024-09-29 18:05:21,084 - 13] DEBUG: chunk length: 200
# [2024-09-29 18:05:21,085 - 8] DEBUG: ./prototype data/celeste_desc_3200.json
# [2024-09-29 18:05:21,103 - 13] DEBUG: chunk length: 200
# [2024-09-29 18:05:21,104 - 8] DEBUG: ./prototype data/celeste_desc_8600.json
# [2024-09-29 18:05:21,125 - 13] DEBUG: chunk length: 200
# [2024-09-29 18:05:21,127 - 8] DEBUG: ./prototype data/celeste_desc_9800.json
# [2024-09-29 18:05:21,148 - 13] DEBUG: chunk length: 200
# [2024-09-29 18:05:21,150 - 8] DEBUG: ./prototype data/celeste_desc_9400.json
# [2024-09-29 18:05:21,167 - 13] DEBUG: chunk length: 200
# [2024-09-29 18:05:21,168 - 8] DEBUG: ./prototype data/celeste_asc_1000.json
# [2024-09-29 18:05:21,198 - 13] DEBUG: chunk length: 200
# [2024-09-29 18:05:21,199 - 8] DEBUG: ./prototype data/celeste_asc_3800.json
# [2024-09-29 18:05:21,212 - 13] DEBUG: chunk length: 200
# [2024-09-29 18:05:21,218 - 8] DEBUG: ./prototype data/celeste_asc_2600.json
# [2024-09-29 18:05:21,244 - 13] DEBUG: chunk length: 200
# [2024-09-29 18:05:21,247 - 8] DEBUG: ./prototype data/celeste_asc_3400.json
# [2024-09-29 18:05:21,272 - 13] DEBUG: chunk length: 200
# [2024-09-29 18:05:21,273 - 8] DEBUG: ./prototype data/celeste_asc_1200.json
# [2024-09-29 18:05:21,299 - 13] DEBUG: chunk length: 200
# [2024-09-29 18:05:21,300 - 8] DEBUG: ./prototype data/celeste_desc_8800.json
# [2024-09-29 18:05:21,311 - 13] DEBUG: chunk length: 200
# [2024-09-29 18:05:21,316 - 8] DEBUG: ./prototype data/celeste_desc_9600.json
# [2024-09-29 18:05:21,331 - 13] DEBUG: chunk length: 200
# [2024-09-29 18:05:21,334 - 8] DEBUG: ./prototype data/celeste_desc_8400.json
# [2024-09-29 18:05:21,355 - 13] DEBUG: chunk length: 200
# [2024-09-29 18:05:21,359 - 8] DEBUG: ./prototype data/celeste_asc_3600.json
# [2024-09-29 18:05:21,378 - 13] DEBUG: chunk length: 200
# [2024-09-29 18:05:21,381 - 8] DEBUG: ./prototype data/celeste_asc_2800.json
# [2024-09-29 18:05:21,398 - 13] DEBUG: chunk length: 200
# [2024-09-29 18:05:21,399 - 8] DEBUG: ./prototype data/celeste_asc_2400.json
# [2024-09-29 18:05:21,425 - 13] DEBUG: chunk length: 200
# [2024-09-29 18:05:21,427 - 8] DEBUG: ./prototype data/celeste_asc_9000.json
# [2024-09-29 18:05:21,444 - 13] DEBUG: chunk length: 200
# [2024-09-29 18:05:21,448 - 8] DEBUG: ./prototype data/celeste_desc_1400.json
# [2024-09-29 18:05:21,467 - 13] DEBUG: chunk length: 200
# [2024-09-29 18:05:21,468 - 8] DEBUG: ./prototype data/celeste_desc_1800.json
# [2024-09-29 18:05:21,489 - 13] DEBUG: chunk length: 200
# [2024-09-29 18:05:21,490 - 8] DEBUG: ./prototype data/celeste_asc_8200.json
# [2024-09-29 18:05:21,513 - 13] DEBUG: chunk length: 200
# [2024-09-29 18:05:21,515 - 8] DEBUG: ./prototype data/celeste_desc_3000.json
# [2024-09-29 18:05:21,537 - 13] DEBUG: chunk length: 200
# [2024-09-29 18:05:21,541 - 8] DEBUG: ./prototype data/celeste_desc_0.json
# [2024-09-29 18:05:21,678 - 13] DEBUG: chunk length: 200
# [2024-09-29 18:05:21,679 - 8] DEBUG: ./prototype data/celeste_asc_200.json
# [2024-09-29 18:05:21,690 - 13] DEBUG: chunk length: 200
# [2024-09-29 18:05:21,695 - 8] DEBUG: ./prototype data/celeste_desc_2200.json
# [2024-09-29 18:05:21,724 - 13] DEBUG: chunk length: 200
# [2024-09-29 18:05:21,726 - 8] DEBUG: ./prototype data/celeste_asc_2000.json
# [2024-09-29 18:05:21,738 - 13] DEBUG: chunk length: 200
# [2024-09-29 18:05:21,742 - 8] DEBUG: ./prototype data/celeste_asc_3200.json
# [2024-09-29 18:05:21,772 - 13] DEBUG: chunk length: 200
# [2024-09-29 18:05:21,773 - 8] DEBUG: ./prototype data/celeste_desc_8000.json
# [2024-09-29 18:05:21,789 - 13] DEBUG: chunk length: 200
# [2024-09-29 18:05:21,790 - 8] DEBUG: ./prototype data/celeste_asc_1600.json
# [2024-09-29 18:05:21,813 - 13] DEBUG: chunk length: 200
# [2024-09-29 18:05:21,814 - 8] DEBUG: ./prototype data/celeste_desc_9200.json
# [2024-09-29 18:05:21,841 - 13] DEBUG: chunk length: 200
# [2024-09-29 18:05:21,843 - 8] DEBUG: ./prototype data/celeste_desc_3800.json
# [2024-09-29 18:05:21,856 - 13] DEBUG: chunk length: 200
# [2024-09-29 18:05:21,861 - 8] DEBUG: ./prototype data/celeste_asc_600.json
# [2024-09-29 18:05:21,890 - 13] DEBUG: chunk length: 200
# [2024-09-29 18:05:21,891 - 8] DEBUG: ./prototype data/celeste_desc_2600.json
# [2024-09-29 18:05:21,907 - 13] DEBUG: chunk length: 200
# [2024-09-29 18:05:21,912 - 8] DEBUG: ./prototype data/celeste_desc_3400.json
# [2024-09-29 18:05:21,950 - 13] DEBUG: chunk length: 200
# [2024-09-29 18:05:21,955 - 8] DEBUG: ./prototype data/celeste_asc_8600.json
# [2024-09-29 18:05:21,971 - 13] DEBUG: chunk length: 200
# [2024-09-29 18:05:21,973 - 8] DEBUG: ./prototype data/celeste_asc_9800.json
# [2024-09-29 18:05:21,996 - 13] DEBUG: chunk length: 200
# [2024-09-29 18:05:21,999 - 8] DEBUG: ./prototype data/celeste_asc_9400.json
# [2024-09-29 18:05:22,025 - 13] DEBUG: chunk length: 200
# [2024-09-29 18:05:22,027 - 8] DEBUG: ./prototype data/celeste_desc_1000.json
# [2024-09-29 18:05:22,061 - 13] DEBUG: chunk length: 200
# [2024-09-29 18:05:22,067 - 8] DEBUG: ./prototype data/celeste_desc_3600.json
# [2024-09-29 18:05:22,080 - 13] DEBUG: chunk length: 200
# [2024-09-29 18:05:22,082 - 8] DEBUG: ./prototype data/celeste_asc_800.json
# [2024-09-29 18:05:22,141 - 13] DEBUG: chunk length: 200
# [2024-09-29 18:05:22,142 - 8] DEBUG: ./prototype data/celeste_desc_2800.json
# [2024-09-29 18:05:22,162 - 13] DEBUG: chunk length: 200
# [2024-09-29 18:05:22,163 - 8] DEBUG: ./prototype data/celeste_desc_2400.json
# [2024-09-29 18:05:22,190 - 13] DEBUG: chunk length: 200
# [2024-09-29 18:05:22,191 - 8] DEBUG: ./prototype data/celeste_asc_400.json
# [2024-09-29 18:05:22,205 - 13] DEBUG: chunk length: 200
# [2024-09-29 18:05:22,213 - 8] DEBUG: ./prototype data/celeste_asc_8800.json
# [2024-09-29 18:05:22,258 - 13] DEBUG: chunk length: 200
# [2024-09-29 18:05:22,262 - 8] DEBUG: ./prototype data/celeste_desc_1200.json
# [2024-09-29 18:05:22,310 - 13] DEBUG: chunk length: 200
# [2024-09-29 18:05:22,318 - 8] DEBUG: ./prototype data/celeste_asc_9600.json
# [2024-09-29 18:05:22,358 - 13] DEBUG: chunk length: 200
# [2024-09-29 18:05:22,359 - 8] DEBUG: ./prototype data/celeste_asc_8400.json
# [2024-09-29 18:05:22,401 - 13] DEBUG: chunk length: 200
# [2024-09-29 18:05:22,403 - 8] DEBUG: ./prototype data/celeste_asc_3000.json
# [2024-09-29 18:05:22,442 - 13] DEBUG: chunk length: 200
# [2024-09-29 18:05:22,448 - 8] DEBUG: ./prototype data/celeste_asc_2200.json
# [2024-09-29 18:05:22,515 - 13] DEBUG: chunk length: 200
# [2024-09-29 18:05:22,523 - 8] DEBUG: ./prototype data/celeste_desc_9000.json
# [2024-09-29 18:05:22,823 - 13] DEBUG: chunk length: 200
# [2024-09-29 18:05:22,825 - 8] DEBUG: ./prototype data/celeste_asc_1400.json
# [2024-09-29 18:05:22,841 - 13] DEBUG: chunk length: 200
# [2024-09-29 18:05:22,843 - 8] DEBUG: ./prototype data/celeste_desc_8200.json
# [2024-09-29 18:05:22,871 - 13] DEBUG: chunk length: 200
# [2024-09-29 18:05:22,873 - 8] DEBUG: ./prototype data/celeste_asc_1800.json
# [2024-09-29 18:05:22,889 - 13] DEBUG: chunk length: 200
# INFO: 20000
# [2024-09-29 18:05:22,893 - 18] DEBUG: {'id': 'zp49vg8z', 'weblink': 'https://www.speedrun.com/celeste/run/zp49vg8z', 'game': 'o1y9j9v6', 'level': None, 'category': '7kjpl1gk', 'videos': {'links': [{'uri': 'https://www.youtube.com/watch?v=7RrUsOp-Bws'}]}, 'comment': None, 'status': {'status': 'verified', 'examiner': '1xy5ngw8', 'verify-date': '2019-10-10T18:18:18Z'}, 'players': {'data': [{'rel': 'user', 'id': 'e8e049dj', 'names': {'international': 'yujene', 'japanese': None}, 'supporterAnimation': False, 'pronouns': None, 'weblink': 'https://www.speedrun.com/user/yujene', 'name-style': {'style': 'gradient', 'color-from': {'light': '#A259C5', 'dark': '#C279E5'}, 'color-to': {'light': '#A259C5', 'dark': '#C279E5'}}, 'role': 'user', 'signup': '2019-01-04T07:05:55Z', 'location': {'country': {'code': 'ca', 'names': {'international': 'Canada', 'japanese': None}}}, 'twitch': {'uri': 'https://www.twitch.tv/yujene'}, 'hitbox': None, 'youtube': None, 'twitter': None, 'speedrunslive': None, 'assets': {'icon': {'uri': 'https://www.speedrun.com/static/user/e8e049dj/icon?v=3531099'}, 'supporterIcon': None, 'image': {'uri': 'https://www.speedrun.com/static/user/e8e049dj/image?v=3d8217b'}}, 'links': [{'rel': 'self', 'uri': 'https://www.speedrun.com/api/v1/users/e8e049dj'}, {'rel': 'runs', 'uri': 'https://www.speedrun.com/api/v1/runs?user=e8e049dj'}, {'rel': 'games', 'uri': 'https://www.speedrun.com/api/v1/games?moderator=e8e049dj'}, {'rel': 'personal-bests', 'uri': 'https://www.speedrun.com/api/v1/users/e8e049dj/personal-bests'}]}]}, 'date': '2019-10-10', 'submitted': '2019-10-10T06:10:51Z', 'times': {'primary': 'PT49M0.252S', 'primary_t': 2940.252, 'realtime': None, 'realtime_t': 0, 'realtime_noloads': None, 'realtime_noloads_t': 0, 'ingame': 'PT49M0.252S', 'ingame_t': 2940.252}, 'system': {'platform': '8gej2n93', 'emulated': False, 'region': None}, 'splits': None, 'values': {'38do9y4l': '9qjxmo0l'}, 'links': [{'rel': 'self', 'uri': 'https://www.speedrun.com/api/v1/runs/zp49vg8z'}, {'rel': 'game', 'uri': 'https://www.speedrun.com/api/v1/games/o1y9j9v6'}, {'rel': 'category', 'uri': 'https://www.speedrun.com/api/v1/categories/7kjpl1gk'}, {'rel': 'platform', 'uri': 'https://www.speedrun.com/api/v1/platforms/8gej2n93'}, {'rel': 'examiner', 'uri': 'https://www.speedrun.com/api/v1/users/1xy5ngw8'}]}

# %%
run_set = set()
unique_runs = [run for run in file_data if run["id"] not in run_set and not run_set.add(run["id"])]

logger.info(len(unique_runs))
# Out:
# INFO: 18746

# %%
outfile_name = "celeste_runs.json"

with open(outfile_name, "w+") as fp:
    logger.debug(f"saving runs to: {outfile_name}")
    json.dump(unique_runs, fp, indent=2)
logger.debug("runs saved")
# Out:
# [2024-09-29 18:07:41,335 - 4] DEBUG: saving runs to: celeste_runs.json
# [2024-09-29 18:07:50,670 - 6] DEBUG: runs saved
